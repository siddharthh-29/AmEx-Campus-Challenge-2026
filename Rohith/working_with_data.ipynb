# %%
import pandas as pd

# %%
pd.read_csv(r'E:\Hackathons\AmEx-Campus-Challenge-2026\6a3eb196bc7a3_campus_challenge_r1_data.csv', index_col = 'id') # alwyas use r in front of paths in python
# Out:
#                   f1  f2  f3         f4            f5          f6  \
# id
# 0           0.000000   0   1   98615.44   5620.938246         NaN
# 1           0.000000   0   0   21241.06  10196.878460  13865.4026
# 2        1224.690475   0   1        NaN     16.160000         NaN
# 3           0.000000   1   0        NaN   1635.316863   3231.1968
# 4        3824.366700   0   0    7140.87   5007.271790   4064.2152
# ...              ...  ..  ..        ...           ...         ...
# 499995      0.000000   0   0  140995.62      0.000000  26017.2042
# 499996  14524.638800   0   0   16548.20    387.496932   7941.0602
# 499997      0.000000   0   0   79328.70   6654.585300      0.0000
# 499998  17967.726330   0   0       2.10   4393.267105      0.0000
# 499999  12518.042340   0   0        NaN    342.760334   3478.0057
#
#                  f7         f8         f9         f10  ...       f14   f15  \
# id                                                     ...
# ...

# %%
pd.read_csv(r'E:\Hackathons\AmEx-Campus-Challenge-2026\6a3eb196bc7a3_campus_challenge_r1_data.csv', index_col = 'id', nrows = 10)
# Out:
#               f1  f2  f3        f4            f5          f6           f7  \
# id
# 0       0.000000   0   1  98615.44   5620.938246         NaN          NaN
# 1       0.000000   0   0  21241.06  10196.878460  13865.4026    425.04840
# 2    1224.690475   0   1       NaN     16.160000         NaN          NaN
# 3       0.000000   1   0       NaN   1635.316863   3231.1968   -269.15308
# 4    3824.366700   0   0   7140.87   5007.271790   4064.2152  16079.35060
# 5   13693.126850   0   0       NaN   1092.540977  18506.0007  10912.45980
# 6       0.000000   0   0  52834.93   8649.815878  16386.3264   -274.64600
# 7   10878.184620   0   0       NaN   2110.565533  33868.1336  40748.36140
# 8    2901.104008   0   1       NaN     47.515737         NaN          NaN
# 9    1794.831500   0   0       NaN  11005.853170    638.0192   4802.10560
#
#            f8         f9          f10  ...       f14  f15        f16      f17  \
# id                                     ...
# ...

# %%
cols = ["id",
    "Average Revolve Balance in last 12m",
    "Cancellation Calls in last 12m",
    "Cancellation Calls due to Collection",
    "Rewards Points Balance",
    "Total Spend in last 12m",
    "Airlines Spend in 12m",
    "Other Spend in 12m",
    "Entertainment Spend in 12m",
    "Lodging Spend in 12m",
    "Dining Spend in 12m",
    "Average Risk Score in 12m",
    "Login Counts to website",
    "Lounge Access Count",
    "Credits used in airlines",
    "Cab benefits usage",
    "Entertainment Credit Used Amount",
    "Total Lend Line Amount",
    "Total Consumer Lend Line Amount",
    "Number of Supplementary Accounts",
    "Count of Active Charge Cards",
    "Rewards point redeemed in 12months",
    "Emails Open in Last 6 months",
    "Emails Clicked in Last 6 months"
]

# %%
df = pd.read_csv(
    r"E:\Hackathons\AmEx-Campus-Challenge-2026\6a3eb196bc7a3_campus_challenge_r1_data.csv",
    names=cols,
    header=0,
    index_col='id'
)
df
# Out:
#         Average Revolve Balance in last 12m  Cancellation Calls in last 12m  \
# id
# 0                                  0.000000                               0
# 1                                  0.000000                               0
# 2                               1224.690475                               0
# 3                                  0.000000                               1
# 4                               3824.366700                               0
# ...                                     ...                             ...
# 499995                             0.000000                               0
# 499996                         14524.638800                               0
# 499997                             0.000000                               0
# 499998                         17967.726330                               0
# 499999                         12518.042340                               0
#
# ...

# %% [markdown]
# # Understanding your Data

# %%
df.shape # shape of the data
# Out:
# (500000, 23)

# %%
df.sample(10) # gives us 10 random samples of data
# Out:
#         Average Revolve Balance in last 12m  Cancellation Calls in last 12m  \
# id
# 104188                            72.668200                               0
# 170905                         17428.694540                               0
# 257953                             0.000000                               0
# 323486                          1943.711334                               1
# 193045                             0.000000                               1
# 393528                         17967.726330                               0
# 469192                          2579.702184                               0
# 423830                             0.000000                               1
# 156481                             0.000000                               0
# 137877                             0.000000                               0
#
#         Cancellation Calls due to Collection  Rewards Points Balance  \
# id
# ...

# %%
df.info() # gives us information regarding null values, count, non-null values
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Average Revolve Balance in last 12m   500000 non-null  float64
#  1   Cancellation Calls in last 12m        500000 non-null  int64
#  2   Cancellation Calls due to Collection  500000 non-null  int64
#  3   Rewards Points Balance                242772 non-null  float64
#  4   Total Spend in last 12m               493660 non-null  float64
#  5   Airlines Spend in 12m                 384302 non-null  float64
#  6   Other Spend in 12m                    384302 non-null  float64
#  7   Entertainment Spend in 12m            384302 non-null  float64
#  8   Lodging Spend in 12m                  384302 non-null  float64
#  9   Dining Spend in 12m                   384302 non-null  float64
# ...

# %%
df.isnull().sum() # gives us total amount of missing values in each column in pandas series format
# Out:
# Average Revolve Balance in last 12m          0
# Cancellation Calls in last 12m               0
# Cancellation Calls due to Collection         0
# Rewards Points Balance                  257228
# Total Spend in last 12m                   6340
# Airlines Spend in 12m                   115698
# Other Spend in 12m                      115698
# Entertainment Spend in 12m              115698
# Lodging Spend in 12m                    115698
# Dining Spend in 12m                     115698
# Average Risk Score in 12m                 2510
# Login Counts to website                  25005
# Lounge Access Count                      13716
# Credits used in airlines                 13716
# Cab benefits usage                       13716
# Entertainment Credit Used Amount         13716
# Total Lend Line Amount                  292254
# Total Consumer Lend Line Amount         309444
# Number of Supplementary Accounts            22
# Count of Active Charge Cards               101
# ...

# %%
df.describe() # gives us some of the mathematical values of each column
# Out:
#        Average Revolve Balance in last 12m  Cancellation Calls in last 12m  \
# count                        500000.000000                   500000.000000
# mean                           2467.312088                        0.173948
# std                            4801.261745                        0.379065
# min                               0.000000                        0.000000
# 25%                               0.000000                        0.000000
# 50%                               0.000000                        0.000000
# 75%                            2436.194862                        0.000000
# max                           17967.726330                        1.000000
#
#        Cancellation Calls due to Collection  Rewards Points Balance  \
# count                         500000.000000           242772.000000
# mean                               0.108608           126607.131109
# std                                0.311147           183366.588497
# ...

# %%
#Duplicate Values in our data
df.duplicated().sum()
# Out:
# np.int64(97)

# %%
# Correlation between cols
# very important to understand the relation between the input cols and output cols
df.corr()
# Out:
#                                       Average Revolve Balance in last 12m  \
# Average Revolve Balance in last 12m                              1.000000
# Cancellation Calls in last 12m                                  -0.201072
# Cancellation Calls due to Collection                             0.173034
# Rewards Points Balance                                          -0.049796
# Total Spend in last 12m                                          0.031887
# Airlines Spend in 12m                                            0.037332
# Other Spend in 12m                                               0.107974
# Entertainment Spend in 12m                                       0.083387
# Lodging Spend in 12m                                             0.073349
# Dining Spend in 12m                                              0.094419
# Average Risk Score in 12m                                        0.196084
# Login Counts to website                                         -0.071236
# ...
